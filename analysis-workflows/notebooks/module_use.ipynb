# %% [markdown]
# ## This notebooks records how often each module was used based on the job scripts run

# %% [markdown]
# Script looks over all the job scripts submitted in `/global/home/groups/scs/slurm/jobscripts` and looks at the module load list.

# %%
import os
import sys
import re
import json
import pandas as pd

# %%
username = 'sera4415'

# %% [markdown]
# ### We only need to run the following cells once to load the information and once with each new month

# %%
# Helper function that parses through each script to find the loaded module
# Input: text string
# Output: list of strings (modules)
def find_modules(text):
    modules = re.findall(r'\module load[^\n;]*', text) # Returns list ie ['module load python', 'module load vim']
    modules = [m[12:] for m in modules] # Parses out 'module load' -> ['python', 'vim']
    out = []
    for m in modules: 
        out += m.split(" ")
    return out

# Helper function that parses through each script to find the username 
# Input: text string
# Output: string username
def find_users(text):
    user = re.findall(r'\#SBATCH --account=[^\n;]*', text) # Returns list ie ['module load python', 'module load vim']
    if len(user) == 0: 
        return 'None'
    return user[0][18:].strip()

# %%
# Maps each month to another dictionary of modules : popularity 
month_modules_dict = {}

# %%
scripts_loc = '/global/home/groups/scs/slurm/jobscripts/'

os.chdir(scripts_loc)

year_folders = os.listdir() 

# Creates mappings for each year/month, telling us which days were used     
month_dict = {}
    
for year in year_folders:
    os.chdir(scripts_loc + year)
    
    day_folders = os.listdir()
    for day in day_folders: 
        month = day[:7]
        if month in month_dict.keys(): 
            month_dict[month].append(day)
        else:
            month_dict[month] = [day]

# %% [markdown]
# Processes each months worth of scripts and saves it to users scratch file
#
# We will be saving each month in a yyyy-mm.json file, in the format of `{"module" : {"user" : {"num_uses" : #}}}`
#
# ### Month by month

# %%
errors = []
user_errors = []

error_dest = '/global/scratch/' + username + '/errors.txt'
user_dest = '/global/scratch/' + username + '/user_errors.txt'
   
# Creates error log files if they don't exist
if not os.path.isfile(error_dest):
    # !touch $error_dest
    
if not os.path.isfile(user_dest):
    # !touch $user_dest
    
month_dict_keys = list(month_dict.keys())
month_dict_keys.sort()

for month in month_dict_keys: 
    # Prints day so we can make sure it's going through all the folders
    print("******", month, "******")
    save_dest = '/global/scratch/' + username + '/' + month + '.json'
    # If the month has already been loaded skips 
    if os.path.isfile(save_dest):
        continue
    day_files = month_dict[month]
    day_files.sort()
    index = 0
    module_dict = {}
    # Goes through each day
    for day in day_files:
        print(day+" ", end="", flush=True)
        index = 0
        dest = scripts_loc + day[:4] + "/" + day
        os.chdir(dest)
        script_files = os.listdir()
        # Then goes through each script per day
        for script in script_files: 
            if index % 100 == 0: 
                print(".", end="", flush=True)
            index += 1
            # Goes through all the scripts in each day 
            try:
                file = open(script, 'r')    
                script_text = file.read()

                # Finds list of all modules and adds them to our dictionay 
                modules = find_modules(script_text)
                user = find_users(script_text)
                if user == 'None':
                    user_errors.append(day + "/" + script)
                for module in modules: 
                    if module in module_dict.keys(): 
                        users_dict = module_dict[module]
                        if user in users_dict.keys():
                            users_dict[user]["num_uses"] += 1
                        else:
                            users_dict[user] = {"num_uses" : 1}
                    else:
                        users_dict = {}
                        users_dict[user] = {"num_uses" : 1}
                        module_dict[module] = users_dict 
            except UnicodeDecodeError:
                print("Unable to load: " + day + "/" + script)
                errors.append(day + "/" + script)
                
        print()
        os.chdir('..')
             
    # !touch $save_dest
    with open(save_dest, 'w') as fp:
        json.dump( module_dict, fp)
        
    with open(error_dest, 'a+') as f: 
        f.write(' '.join(errors))
    errors = []
    with open(error_dest, 'a+') as f: 
        f.write(' '.join(user_errors))
    user_errors = []
        
    month_modules_dict[month] = module_dict
# Out:
# ****** 2016-09 ******
# ****** 2016-10 ******
# ****** 2016-11 ******
# ****** 2016-12 ******
# ****** 2017-01 ******
# ****** 2017-02 ******
# ****** 2017-03 ******
# ****** 2017-04 ******
# ****** 2017-05 ******
# ****** 2017-06 ******
# ****** 2017-07 ******
# ****** 2017-08 ******
# ****** 2017-09 ******
# ****** 2017-10 ******
# ****** 2017-11 ******
# ****** 2017-12 ******
# ****** 2018-01 ******
# ****** 2018-02 ******
# 2018-02-01 ..
# /global/software/sl-7.x86_64/modules/langs/python/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: bad escape \m
#   """
# ................
# 2018-02-02 .........................
# 2018-02-03 ....................................
# 2018-02-04 .......................................................................
# 2018-02-05 ...................
# 2018-02-06 ..............................
# 2018-02-07 ..................
# 2018-02-08 ........................
# 2018-02-09 ..........................
# 2018-02-10 ............
# 2018-02-11 .....
# 2018-02-12 ............
# 2018-02-13 ...............
# 2018-02-14 ...........
# 2018-02-15 ....Unable to load: 2018-02-15/job2162833
# .
# 2018-02-16 .......
# 2018-02-17 ......
# 2018-02-18 ....
# 2018-02-19 .......
# 2018-02-20 ..........
# 2018-02-21 ..........
# 2018-02-22 ................................
# 2018-02-23 .............
# 2018-02-24 ....
# 2018-02-25 ........
# 2018-02-26 ....................
# 2018-02-27 ...........................
# 2018-02-28 ..................
# ****** 2018-03 ******
# 2018-03-01 .........................
# 2018-03-02 ...............
# 2018-03-03 .......
# 2018-03-04 ...
# 2018-03-05 .........
# 2018-03-06 ..........
# 2018-03-07 .....................................................................................................................................
# 2018-03-08 .................................................................
# 2018-03-09 ........................................................................................
# 2018-03-10 ...............................................................
# 2018-03-11 .......................................
# 2018-03-12 .
# 2018-03-13 .......................................................................
# 2018-03-14 ...........................................................
# 2018-03-15 ................................................................
# 2018-03-16 ...............................................................................
# 2018-03-17 .................................................................
# 2018-03-18 ................................................................................
# 2018-03-19 ............................................................................
# 2018-03-20 .......................................................................................................................................
# 2018-03-21 ..........................................................................Unable to load: 2018-03-21/job2427558
# .........................................................Unable to load: 2018-03-21/job2427566
# ......................................
# 2018-03-22 ....................................................................................................................................................................................
# 2018-03-23 ........................................................................................................................................................
# 2018-03-24 ............................................................
# 2018-03-25 ...............................................................................
# 2018-03-26 .....................................................................................
# 2018-03-27 .......................................................................
# 2018-03-28 .......................................
# 2018-03-29 ..........................
# 2018-03-30 ............................................
# 2018-03-31 ..............................
# ****** 2018-04 ******
# 2018-04-01 ................
# 2018-04-02 .................
# 2018-04-03 ..........................
# 2018-04-04 ..............................
# 2018-04-05 ........................
# 2018-04-06 ................
# 2018-04-07 .............
# 2018-04-08 ...........
# 2018-04-09 ....................................................
# 2018-04-10 ..............................
# 2018-04-11 .........................
# 2018-04-12 ............................
# 2018-04-13 ........................
# 2018-04-14 ...................
# 2018-04-15 ...................
# 2018-04-16 ..........Unable to load: 2018-04-16/job2921890
# ..........
# 2018-04-17 .................
# 2018-04-18 ............
# 2018-04-19 ...................
# 2018-04-20 ....................
# 2018-04-21 ............
# 2018-04-22 ...Unable to load: 2018-04-22/job2931963
# ...
# 2018-04-23 ...........................
# 2018-04-24 .................................
# 2018-04-25 ..........................................
# 2018-04-26 ..............
# 2018-04-27 ..................................
# 2018-04-28 ..............
# 2018-04-29 ..............................
# 2018-04-30 ..........................

# %% [markdown]
# ### All months

# %%
errors = []
user_errors = []

error_dest = '/global/scratch/' + username + '/total_errors.txt'
user_dest = '/global/scratch/' + username + '/total_user_errors.txt'
save_dest = '/global/scratch/' + username + '/total.json'   

month_dict_keys = list(month_dict.keys())
month_dict_keys.sort()

module_dict = {}

for month in month_dict_keys: 
    # Prints day so we can make sure it's going through all the folders
    print("******", month, "******")
    day_files = month_dict[month]
    day_files.sort()
    index = 0
    # Goes through each day
    for day in day_files:
        print(day+" ", end="", flush=True)
        index = 0
        os.chdir(day)
        script_files = os.listdir()
        # Then goes through each script per day
        for script in script_files: 
            if index % 100 == 0: 
                print(".", end="", flush=True)
            index += 1
            # Goes through all the scripts in each day 
            try:
                file = open(script, 'r')    
                script_text = file.read()

                # Finds list of all modules and adds them to our dictionay 
                modules = find_modules(script_text)
                user = find_users(script_text)
                if user == 'None':
                    user_errors.append(day + "/" + script)
                for module in modules: 
                    if module in module_dict.keys(): 
                        users_dict = module_dict[module]
                        if user in users_dict.keys():
                            users_dict[user]["num_uses"] += 1
                        else:
                            users_dict[user] = {"num_uses" : 1}
                    else:
                        users_dict = {}
                        users_dict[user] = {"num_uses" : 1}
                        module_dict[module] = users_dict 
            except UnicodeDecodeError:
                print("Unable to load: " + day + "/" + script)
                errors.append(day + "/" + script)
                
        print()
        os.chdir('..')
      
    
    
# !touch $save_dest
with open(save_dest, 'w') as fp:
    json.dump( module_dict, fp)

# Creates error log files if they don't exist
if not os.path.isfile(error_dest):
    # !touch $error_dest
    with open(error_dest, 'a+') as f: 
        f.write(' '.join(errors))
        
if not os.path.isfile(user_dest):
    # !touch $user_dest
    with open(user_dest, 'a+') as f: 
        f.write(' '.join(user_errors))
# Out:
# ****** 2016-09 ******
# 2016-09-15 .
# 2016-09-21 ....
# /global/software/sl-7.x86_64/modules/langs/python/3.5/lib/python3.5/site-packages/ipykernel_launcher.py
# 2018-01-09 ..................
# 2018-01-10 ..........................
# 2018-01-11 ......................................................
# 2018-01-12 ..............................................
# 2018-01-13 ......
# 2018-01-14 .............................................
# 2018-01-15 ......................................................................................................................
# 2018-01-16 .............................
# 2018-01-17 .......................
# 2018-01-18 .................
# 2018-01-19 ............................
# 2018-01-20 ............................
# 2018-01-21 ..................................
# 2018-01-22 ...................
# 2018-01-23 .....

# %% [markdown]
# ### Loads saved information and makes visuals from them

# %%
# Insert month you want displayed here
month = 'total'
path = '/global/scratch/' + username + '/' + month + '.json'
with open(path, 'r') as fp:
    data = json.load(fp)
    df = pd.DataFrame.from_dict({(i,j): data[i][j] 
                       for i in data.keys() 
                       for j in data[i].keys()},
                   orient='index')
df
    # loop through all modules and graph its user per user
# Out:
#                                                                                     num_uses
#                                 None                                                   29059
#                                 ac_adesnik                                               224
#                                 ac_cdcal                                                   6
#                                 ac_neander                                                11
#                                 ac_scsguest                                              614
#                                 aiolos_savio_normal                                        2
#                                 co_aiolos                                               1307
#                                 co_astro                                                 129
#                                 co_bachtrog                                               19
#                                 co_lsdi\t\t#Repository to be charged to: co_lsdi           5
#                                 co_msedcc                                               2768
#                                 co_nuclear                                               707
#                                 co_rosalind                                              905
#                                 co_rosalind                                    ...         2
#                                 co_stat                                                    3
#                                 fc_alphaSim                                              554
#                                 fc_biome                                                  48
#                                 fc_blackman                                              297
#                                 fc_ceder                                                8947
#                                 fc_esdl                                                  177
#                                 fc_flyminer                                              156
#                                 fc_flysong                                               273
#                                 fc_gold                                                   11
#                                 fc_gyemigrants                                           126
#                                 fc_mdasta                                               7465
#                                 fc_millibot                                                9
#                                 fc_mountain                                                1
#                                 fc_msedcc                                                 28
#                                 fc_myshake                                                67
#                                 fc_neuronident                                            59
# ...                                                                                      ...
# vim/7.4                         co_acrb                                                   39
# virtualenv                      None                                                       9
#                                 co_laika                                                1119
#                                 fc_blackman                                              112
#                                 fc_hedm                                                    3
#                                 fc_neutronics                                              5
#                                 fc_switch                                                 62
# virtualenv/1.7.2                None                                                      30
# visit                           None                                                       1
# vmd                             co_acrb                                                  859
#                                 co_lsdi\t\t#Repository to be charged to: co_lsdi          21
#                                 fc_acrb                                                   86
# vsearch                         fc_flyminer                                               18
# vsearch/1.11.1                  None                                                      15
# vtk                             co_astro                                                 129
# vtk/5.10.1                      fc_biome                                                   1
# with                            None                                                     233
#                                 fc_esdl                                                  376
#                                 vector_rileylab                                            8
# works                           None                                                      64
#                                 vector_rileylab                                            8
# xz                              co_rosalind                                               92
# xz/5.2.3                        co_rosalind                                               87
#                                 fc_blackman                                               94
#                                 vector_blackmanlab                                         3
# zlib/1.2.8                      co_rosalind                                               87
#                                 fc_blackman                                               68
#                                 vector_blackmanlab                                         3
# zsh/5.0.0                       None                                                      14
# ~/qmc/ticktock_w/build/bin/fqmc co_chemqmc                                                 1
#
# [1627 rows x 1 columns]
