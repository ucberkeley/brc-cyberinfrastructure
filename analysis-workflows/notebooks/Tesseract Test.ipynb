# %% [markdown]
# ### This notebook is an exemplar which demonstrates transferring files between a Box folder and Savio scratch to run OCR on images using Tesseract (inside a Singularity container)
#
# ( tested with boxsdk (2.0.0a2) on python 3.5 kernel)
# pip install -Iv boxsdk==2.0.0a2

# %% [markdown]
# _This software is available under the terms of the Educational Community License, Version 2.0 (ECL 2.0). This software is Copyright 2016 The Regents of the University of California, Berkeley ("Berkeley")._
#
# The text of the ECL license is reproduced below.
#
# Educational Community License, Version 2.0
# *************************************
# Copyright 2016 The Regents of the University of California, Berkeley ("Berkeley")
#
# Educational Community License, Version 2.0, April 2007
#
# The Educational Community License version 2.0 ("ECL") consists of the
# Apache 2.0 license, modified to change the scope of the patent grant in
# section 3 to be specific to the needs of the education communities using
# this license. The original Apache 2.0 license can be found at:[http://www.apache.org/licenses/LICENSE-2.0]

# %% [markdown]
# Set of target and source directories, script file names and other used as parameters in processing below.

# %%
runFolder = '/global/home/users/mmanning/'

tesseractimage = '/global/scratch/mmanning/tesseract2.img'
tesseractdatadir = '/opt/tessdata/'
pdfnamelist = []

boxProjectFolder = 'TesseractNotebook'
scratchDataDirectory = '/global/scratch/mmanning/tesseractnotebook/'
tesseractScratchDataDirectory = '/scratch/'

SINGULARITYCMD = 'singularity exec -B /global/scratch/mmanning/tesseractnotebook:/scratch  /global/scratch/mmanning/tesseract2.img'

# %% [markdown]
# function to store the oauth2 refresh token in a local file. This can be modified to use a keychain or other as required.

# %%
def store_tokens(access_token, refresh_token):
    
    """Callback for storing refresh tokens. (For now we ignore access tokens)."""
    with open('apptoken.cfg', 'w') as f:
     f.write(refresh_token.strip())

# %% [markdown]
# Oauth2 information is read from a local file with three lines, one line per parameter.
# The client id and client secret are defined in the Box application created for this notebook.  Create the application at the Box Developers site: https://berkeley.app.box.com/developers/services/edit/
#
# The redirect uri can be any site that requires validation. Run the bootstrap notebook to create initial
# tokens that are then continually refreshed

# %%
import os

CLIENT_ID = None
CLIENT_SECRET = None
REDIRECT_URI = None
os.chdir('/global/home/users/mmanning')
# Read app info from text file
with open('app.cfg', 'r') as app_cfg:
    CLIENT_ID = app_cfg.readline()
    CLIENT_SECRET = app_cfg.readline()
    REDIRECT_URI = app_cfg.readline()

# %% [markdown]
# The refresh token is read from a local file. This token was created by running the bootstrap notebook which requires the user to validate with CalNet Authentication Service credentials, then stores the returned auth and refresh tokens in the same config files.

# %%
REFRESH_TOKEN = None

# Read app info from text file
with open('apptoken.cfg', 'r') as apptoken_cfg:
    REFRESH_TOKEN = apptoken_cfg.readline()

# %% [markdown]
# ### Perform autentication
# then create globus client
# Verify client is working by retrieving the name of the users root folder in Box

# %%
from boxsdk import OAuth2
from boxsdk import Client

# Do OAuth2 authorization.
oauth = OAuth2(
    client_id=CLIENT_ID.strip(),
    client_secret=CLIENT_SECRET.strip(),
    refresh_token=REFRESH_TOKEN.strip(),
    store_tokens=store_tokens
)

client = Client(oauth)

root_folder = client.folder(folder_id='0').get()
print ("folder name: ", root_folder['name'] )

items = client.folder(folder_id='0').get_items(limit=100, offset=0)
#print ("items: ", items )
# Out:
# folder name:  All Files

# %% [markdown]
# __function to find folder id be folder name.__
# Current SDK does not have a 'find by name' function so musst loop thru all folders and look for match.

# %%
def find_folder_id(folder_name):
    folderlist = client.search(query=folder_name, result_type='folder', limit=10, offset=0)
    
    if len(folderlist) == 0 or len(folderlist) > 1:
        print('folder not found: ', folder_name)
        return 0
    else:
        return folderlist[0]['id']

# %% [markdown]
# ### Retrieve the pdfs from the Box folder.
# currently the Box SDK does not have an option for finding a folder by name so if you are looking for a specific folder then you would need to loop thru all the items in the list below and do a name match. Once you find the folder and retrieve the id, you can save that id for subsequent runs. Another option is to get the id from the url in the web client, but approah below is more flexible for now.

# %%
import os
import shutil 

print ('current working directory: ', os.getcwd())
os.chdir(scratchDataDirectory)

# test folder contents
items = client.folder(folder_id='0').get_items(limit=20, offset=0)
if type(items) is list:
    print ('number of files in top folder: ', len(items) )
    
    targetfolderId = ''
    for item in items:
        if item['type'] == 'folder':
            print('folder name: ', item['name'])
            if item['name'] == boxProjectFolder:
                targetfolderId = item['id']
                print('targetfolderId: ', targetfolderId)
        
    if targetfolderId is not None:
        tgtitems = client.folder(folder_id=targetfolderId).get_items(limit=200, offset=0)
        if type(tgtitems) is list:
            print ('number of files in target folder: ', len(tgtitems) ) 
        
        # download all pdf files
        for tgtitem in tgtitems:
            if  not tgtitem['type'] == 'folder' and tgtitem['name'].endswith('.pdf'):
                print('downloading: ', tgtitem['name'])
                #pdfcontent = client.file(file_id=tgtitem['id']).content()
                #newfile = open(scratchDataDirectory + tgtitem['name'], 'wb')
                #newfile.write(pdfcontent)
                #newfile.close()
# Out:
# current working directory:  /global/home/users/mmanning
# number of files in top folder:  15
# folder name:  actest
# folder name:  backupTest
# folder name:  cista Santa ISa
# folder name:  Connected Corridors Data
# folder name:  sdktest
# folder name:  TesseractExperiment
# folder name:  TesseractNotebook
# targetfolderId:  15846133956
# folder name:  test for Photoscan
# number of files in target folder:  2
# downloading:  OAAS 1 - OA Bib, 2003.pdf
# downloading:  OACC, 1976.pdf

# %% [markdown]
# clean up filenames to reduce issues

# %%
# !for f in *\ *; do mv "$f" "${f//[^A-Za-z0-9._-]/_}"; done

# %% [markdown]
# ### Convert all pdf files in working directory to images

# %%
def runGhostscript(pdfFile):
    print("filename: ", pdfFile)
    if filename.endswith(".pdf") : 
        name, extension = os.path.splitext(pdfFile)
        
        # Ghostscript executable is inside the container.
        # TEMPLATE: gs -dBATCH -dNOPAUSE -dQUIET -sDEVICE=png16m -sOutputFile=/scratch/test/output/test-%d.png -r300 /scratch/test/germanocr.pdf
        GHOSTSCRIPTCMD = 'gs -dBATCH -dNOPAUSE -dQUIET -sDEVICE=png16m -sOutputFile={}{}-%d.png -r300 {}{}'
        gcmd = GHOSTSCRIPTCMD.format(tesseractScratchDataDirectory, name, tesseractScratchDataDirectory,pdfFile )

        # 
        # convert pdf to png
        #
        print("singularity cmd: ", SINGULARITYCMD)
        print("gs cmd: ", gcmd)
        #result = subprocess.call(GHOSTSCRIPTCMD)
        result = !$SINGULARITYCMD $gcmd
        print("gs result: ", result)

# %%
pdffileList = []
for filename in os.listdir(scratchDataDirectory):
    print("filename: ", filename)
    if filename.endswith(".pdf") : 
        pdffileList.append(filename)
        
        name, extension = os.path.splitext(filename)
        pdfnamelist.append(name)
        
print("pdffileList: ", pdffileList)
print("filenameList: ", pdfnamelist )


#
# multiprocess the pdf to png work work
#
#pool0 = Pool(20)
#pool0.map(runGhostscript, pdffileList)
#pool0.close()
#pool0.join()
# Out:
# filename:  OACC__1976-175.png
# filename:  OACC__1976-116.png
# filename:  OAAS_1_-_OA_Bib__2003-123.txt
# filename:  OAAS_1_-_OA_Bib__2003-120.txt
# filename:  OACC__1976-25.txt
# filename:  OACC__1976-9.txt
# filename:  OAAS_1_-_OA_Bib__2003-55.txt
# filename:  OACC__1976-125.txt
# filename:  OACC__1976-179.png
# filename:  OACC__1976-150.png
# filename:  OAAS_1_-_OA_Bib__2003-19.png
# filename:  OACC__1976-147.txt
# filename:  OACC__1976-136.txt
# filename:  OAAS_1_-_OA_Bib__2003-94.png
# filename:  OACC__1976-100.png
# filename:  OAAS_1_-_OA_Bib__2003-110.png
# filename:  OACC__1976-127.png
# filename:  OACC__1976-72.png
# filename:  OAAS_1_-_OA_Bib__2003-112.txt
# filename:  OACC__1976-69.txt
# filename:  OAAS_1_-_OA_Bib__2003-48.png
# filename:  OAAS_1_-_OA_Bib__2003-116.txt
# filename:  OAAS_1_-_OA_Bib__2003-42.png
# filename:  OAAS_1_-_OA_Bib__2003-6.txt
# filename:  OAAS_1_-_OA_Bib__2003-97.txt
# filename:  OAAS_1_-_OA_Bib__2003-66.png
# filename:  OAAS_1_-_OA_Bib__2003-122.txt
# filename:  OACC__1976-12.txt
# filename:  OACC__1976-205.txt
# filename:  OACC__1976-21.png
# filename:  OAAS_1_-_OA_Bib__2003-31.txt
# filename:  OACC__1976-182.txt
# filename:  OAAS_1_-_OA_Bib__2003-126.png
# filename:  OAAS_1_-_OA_Bib__2003-78.png
# filename:  OAAS_1_-_OA_Bib__2003-69.png
# filename:  OAAS_1_-_OA_Bib__2003-127.txt
# filename:  OAAS_1_-_OA_Bib__2003-115.png
# filename:  OAAS_1_-_OA_Bib__2003-15.png
# filename:  OACC__1976-22.txt
# filename:  OAAS_1_-_OA_Bib__2003-17.png
# filename:  OAAS_1_-_OA_Bib__2003-76.txt
# filename:  OACC__1976-112.png
# filename:  OACC__1976-113.txt
# filename:  OAAS_1_-_OA_Bib__2003-124.txt
# filename:  OAAS_1_-_OA_Bib__2003-111.txt
# filename:  OAAS_1_-_OA_Bib__2003-104.txt
# filename:  OAAS_1_-_OA_Bib__2003-108.txt
# filename:  OACC__1976-93.png
# filename:  OAAS_1_-_OA_Bib__2003-12.txt
# filename:  OACC__1976-209.png
# filename:  OACC__1976-194.png
# filename:  OAAS_1_-_OA_Bib__2003-41.txt
# filename:  OACC__1976-11.txt
# filename:  OACC__1976-170.png
# filename:  OACC__1976-48.txt
# filename:  OACC__1976-57.txt
# filename:  OAAS_1_-_OA_Bib__2003-67.png
# filename:  OAAS_1_-_OA_Bib__2003-32.png
# filename:  OACC__1976-136.png
# filename:  OAAS_1_-_OA_Bib__2003-121.png
# filename:  OACC__1976-74.png
# filename:  OACC__1976-68.png
# filename:  OACC__1976-61.txt
# filename:  OAAS_1_-_OA_Bib__2003-102.txt
# filename:  OAAS_1_-_OA_Bib__2003-1.txt
# filename:  OACC__1976-157.png
# filename:  OACC__1976-36.png
# filename:  OACC__1976-29.png
# filename:  OAAS_1_-_OA_Bib__2003-95.txt
# filename:  OAAS_1_-_OA_Bib__2003-68.png
# filename:  OAAS_1_-_OA_Bib__2003-85.png
# filename:  OACC__1976-124.png
# filename:  OAAS_1_-_OA_Bib__2003-10.txt
# filename:  OACC__1976-174.png
# filename:  OACC__1976-193.txt
# filename:  OAAS_1_-_OA_Bib__2003-96.txt
# filename:  OAAS_1_-_OA_Bib__2003-74.txt
# filename:  OACC__1976-129.txt
# filename:  OAAS_1_-_OA_Bib__2003-60.txt
# filename:  OACC__1976-194.txt
# filename:  OAAS_1_-_OA_Bib__2003-4.txt
# filename:  OACC__1976-142.txt
# filename:  OACC__1976-64.txt
# filename:  OACC__1976-86.png
# filename:  OAAS_1_-_OA_Bib__2003-84.png
# filename:  OACC__1976-129.png
# filename:  OACC__1976-118.txt
# filename:  OACC__1976-67.txt
# filename:  OAAS_1_-_OA_Bib__2003-68.txt
# filename:  OACC__1976-197.txt
# filename:  OAAS_1_-_OA_Bib__2003-59.txt
# filename:  OAAS_1_-_OA_Bib__2003-106.txt
# filename:  OACC__1976-113.png
# filename:  OAAS_1_-_OA_Bib__2003-117.txt
# filename:  OACC__1976-65.png
# filename:  OACC__1976-153.txt
# filename:  OACC__1976-133.png
# filename:  OACC__1976-1.png
# filename:  OACC__1976-4.png
# filename:  OAAS_1_-_OA_Bib__2003-11.txt
# filename:  OAAS_1_-_OA_Bib__2003-60.png
# filename:  OAAS_1_-_OA_Bib__2003-101.png
# filename:  OACC__1976-70.png
# filename:  OACC__1976-186.txt
# filename:  OACC__1976-195.png
# filename:  OACC__1976-35.png
# filename:  OAAS_1_-_OA_Bib__2003-50.txt
# filename:  OACC__1976-105.png
# filename:  OACC__1976-68.txt
# filename:  OACC__1976-80.txt
# filename:  OACC__1976-159.txt
# filename:  OACC__1976-16.txt
# filename:  OACC__1976-45.png
# filename:  OACC__1976-177.png
# filename:  OACC__1976-74.txt
# filename:  OAAS_1_-_OA_Bib__2003-16.png
# filename:  OAAS_1_-_OA_Bib__2003-105.txt
# filename:  OAAS_1_-_OA_Bib__2003-92.txt
# filename:  OAAS_1_-_OA_Bib__2003-9.png
# filename:  OAAS_1_-_OA_Bib__2003-81.png
# filename:  OAAS_1_-_OA_Bib__2003-49.png
# filename:  OACC__1976-182.png
# filename:  OACC__1976-154.png
# filename:  OAAS_1_-_OA_Bib__2003-82.txt
# filename:  OACC__1976-34.png
# filename:  OACC__1976-91.png
# filename:  OAAS_1_-_OA_Bib__2003-97.png
# filename:  OAAS_1_-_OA_Bib__2003-106.png
# filename:  OAAS_1_-_OA_Bib__2003-114.png
# filename:  OAAS_1_-_OA_Bib__2003-65.txt
# filename:  OACC__1976-86.txt
# filename:  OACC__1976-140.png
# filename:  OACC__1976-111.txt
# filename:  OAAS_1_-_OA_Bib__2003-25.png
# filename:  OACC__1976-128.png
# filename:  OACC__1976-98.txt
# filename:  OACC__1976-4.txt
# filename:  OACC__1976-119.txt
# filename:  OACC__1976-173.txt
# filename:  OACC__1976-89.txt
# filename:  OACC__1976-138.png
# filename:  OAAS_1_-_OA_Bib__2003-79.txt
# filename:  OAAS_1_-_OA_Bib__2003-94.txt
# filename:  OACC__1976-28.txt
# filename:  OACC__1976-3.txt
# filename:  OACC__1976-82.txt
# filename:  OAAS_1_-_OA_Bib__2003-78.txt
# filename:  OACC__1976-78.txt
# filename:  OACC__1976-165.png
# filename:  OACC__1976-10.png
# filename:  OAAS_1_-_OA_Bib__2003-87.txt
# filename:  OACC__1976-54.txt
# filename:  OAAS_1_-_OA_Bib__2003-89.png
# filename:  OAAS_1_-_OA_Bib__2003-76.png
# filename:  OACC__1976-114.txt
# filename:  OACC__1976-177.txt
# filename:  OACC__1976-31.png
# filename:  OAAS_1_-_OA_Bib__2003-26.png
# filename:  OACC__1976-104.txt
# filename:  OAAS_1_-_OA_Bib__2003-37.txt
# filename:  OACC__1976-137.txt
# filename:  OACC__1976-44.png
# filename:  OACC__1976-42.png
# filename:  OAAS_1_-_OA_Bib__2003-80.txt
# filename:  OACC__1976-72.txt
# filename:  OACC__1976-31.txt
# filename:  OACC__1976-207.txt
# filename:  OACC__1976-32.png
# filename:  OACC__1976-26.txt
# filename:  OACC__1976-163.png
# filename:  OAAS_1_-_OA_Bib__2003-48.txt
# filename:  OAAS_1_-_OA_Bib__2003-80.png
# filename:  OAAS_1_-_OA_Bib__2003-23.txt
# filename:  OAAS_1_-_OA_Bib__2003-73.png
# filename:  OACC__1976-184.txt
# filename:  OACC__1976-103.txt
# filename:  OAAS_1_-_OA_Bib__2003-2.png
# filename:  OACC__1976-196.png
# filename:  OACC__1976-34.txt
# filename:  OAAS_1_-_OA_Bib__2003-39.txt
# filename:  OAAS_1_-_OA_Bib__2003-38.txt
# filename:  OACC__1976-81.png
# filename:  OACC__1976-145.txt
# filename:  OAAS_1_-_OA_Bib__2003-33.png
# filename:  OAAS_1_-_OA_Bib__2003.pdf
# filename:  OAAS_1_-_OA_Bib__2003-11.png
# filename:  OACC__1976-51.txt
# filename:  OAAS_1_-_OA_Bib__2003-5.txt
# filename:  OACC__1976-166.png
# filename:  OACC__1976-205.png
# filename:  OAAS_1_-_OA_Bib__2003-109.png
# filename:  OACC__1976-92.txt
# filename:  OACC__1976-60.png
# filename:  OAAS_1_-_OA_Bib__2003-91.png
# filename:  OACC__1976-63.png
# filename:  OACC__1976-168.txt
# filename:  OACC__1976-172.txt
# filename:  OAAS_1_-_OA_Bib__2003-115.txt
# filename:  OACC__1976-203.txt
# filename:  OAAS_1_-_OA_Bib__2003-34.png
# filename:  OAAS_1_-_OA_Bib__2003-35.txt
# filename:  OACC__1976-181.txt
# filename:  OACC__1976-210.txt
# filename:  OACC__1976-185.txt
# filename:  OACC__1976-126.txt
# filename:  OAAS_1_-_OA_Bib__2003-125.png
# filename:  OAAS_1_-_OA_Bib__2003-121.txt
# filename:  OAAS_1_-_OA_Bib__2003-56.png
# filename:  OAAS_1_-_OA_Bib__2003-35.png
# filename:  OACC__1976-192.txt
# filename:  OACC__1976-17.txt
# filename:  OACC__1976-199.png
# filename:  OACC__1976-99.txt
# filename:  OAAS_1_-_OA_Bib__2003-28.txt
# filename:  OACC__1976-163.txt
# filename:  OAAS_1_-_OA_Bib__2003-6.png
# filename:  OAAS_1_-_OA_Bib__2003-27.txt
# filename:  OACC__1976-143.png
# filename:  OACC__1976-15.txt
# filename:  OAAS_1_-_OA_Bib__2003-125.txt
# filename:  OACC__1976-50.txt
# filename:  OACC__1976-95.txt
# filename:  OACC__1976-78.png
# filename:  OACC__1976-39.png
# filename:  OACC__1976-152.txt
# filename:  OACC__1976-96.png
# filename:  OACC__1976-108.png
# filename:  OAAS_1_-_OA_Bib__2003-113.png
# filename:  OACC__1976-148.png
# filename:  OACC__1976-151.txt
# filename:  OAAS_1_-_OA_Bib__2003-107.png
# filename:  OACC__1976-134.png
# filename:  OACC__1976-135.png
# filename:  OACC__1976-48.png
# filename:  OAAS_1_-_OA_Bib__2003-25.txt
# filename:  OAAS_1_-_OA_Bib__2003-18.txt
# filename:  OACC__1976-169.txt
# filename:  OAAS_1_-_OA_Bib__2003-7.png
# filename:  OACC__1976-22.png
# filename:  OACC__1976-166.txt
# filename:  OACC__1976-92.png
# filename:  OAAS_1_-_OA_Bib__2003-83.png
# filename:  OAAS_1_-_OA_Bib__2003-24.txt
# filename:  OACC__1976-36.txt
# filename:  OACC__1976-55.txt
# filename:  OAAS_1_-_OA_Bib__2003-55.png
# filename:  OAAS_1_-_OA_Bib__2003-107.txt
# filename:  OACC__1976-39.txt
# filename:  OACC__1976-150.txt
# filename:  OACC__1976-5.png
# filename:  OACC__1976-27.png
# filename:  OAAS_1_-_OA_Bib__2003-24.png
# filename:  OACC__1976-131.png
# filename:  OACC__1976-41.txt
# filename:  OACC__1976-24.txt
# filename:  OACC__1976-155.png
# filename:  OACC__1976-132.png
# filename:  OACC__1976-111.png
# filename:  OACC__1976-94.png
# filename:  OACC__1976-13.txt
# filename:  OACC__1976-82.png
# filename:  OACC__1976-178.txt
# filename:  OACC__1976-97.txt
# filename:  OACC__1976-77.png
# filename:  OACC__1976-85.png
# filename:  OACC__1976-16.png
# filename:  OACC__1976-151.png
# filename:  OACC__1976-32.txt
# filename:  OACC__1976-50.png
# filename:  OACC__1976-87.txt
# filename:  OACC__1976-143.txt
# filename:  OACC__1976-102.txt
# filename:  OAAS_1_-_OA_Bib__2003-83.txt
# filename:  OAAS_1_-_OA_Bib__2003-72.png
# filename:  OACC__1976-193.png
# filename:  OAAS_1_-_OA_Bib__2003-22.txt
# filename:  OAAS_1_-_OA_Bib__2003-42.txt
# filename:  OAAS_1_-_OA_Bib__2003-86.txt
# filename:  OAAS_1_-_OA_Bib__2003-38.png
# filename:  OACC__1976-119.png
# filename:  OAAS_1_-_OA_Bib__2003-117.png
# filename:  OACC__1976-123.txt
# filename:  OACC__1976-103.png
# filename:  OACC__1976-58.png
# filename:  OAAS_1_-_OA_Bib__2003-36.png
# filename:  OACC__1976-40.png
# filename:  OACC__1976-181.png
# filename:  OACC__1976-130.txt
# filename:  OAAS_1_-_OA_Bib__2003-49.txt
# filename:  OAAS_1_-_OA_Bib__2003-74.png
# filename:  OACC__1976-58.txt
# filename:  OAAS_1_-_OA_Bib__2003-43.txt
# filename:  OACC__1976-45.txt
# filename:  OACC__1976-128.txt
# filename:  OAAS_1_-_OA_Bib__2003-20.png
# filename:  OACC__1976-161.txt
# filename:  OACC__1976-53.png
# filename:  OAAS_1_-_OA_Bib__2003-33.txt
# filename:  OACC__1976-8.png
# filename:  OACC__1976-142.png
# filename:  OACC__1976-109.txt
# filename:  OACC__1976-164.png
# filename:  OAAS_1_-_OA_Bib__2003-100.png
# filename:  OACC__1976-160.txt
# filename:  OACC__1976-65.txt
# filename:  OACC__1976-19.png
# filename:  OAAS_1_-_OA_Bib__2003-53.png
# filename:  OAAS_1_-_OA_Bib__2003-20.txt
# filename:  OACC__1976-89.png
# filename:  OACC__1976-7.png
# filename:  OACC__1976-152.png
# filename:  OACC__1976-175.txt
# filename:  OAAS_1_-_OA_Bib__2003-103.txt
# filename:  OACC__1976-117.txt
# filename:  OACC__1976-8.txt
# filename:  OACC__1976-106.png
# filename:  OACC__1976-98.png
# filename:  OACC__1976-105.txt
# filename:  OACC__1976-43.txt
# filename:  OAAS_1_-_OA_Bib__2003-88.png
# filename:  OACC__1976-14.txt
# filename:  OACC__1976-115.png
# filename:  OACC__1976-46.txt
# filename:  OAAS_1_-_OA_Bib__2003-99.txt
# filename:  OACC__1976-53.txt
# filename:  OACC__1976-115.txt
# filename:  OAAS_1_-_OA_Bib__2003-44.txt
# filename:  OACC__1976-75.txt
# filename:  OACC__1976-101.png
# filename:  OACC__1976-62.txt
# filename:  OAAS_1_-_OA_Bib__2003-8.txt
# filename:  OAAS_1_-_OA_Bib__2003-84.txt
# filename:  OACC__1976-159.png
# filename:  OAAS_1_-_OA_Bib__2003-19.txt
# filename:  OACC__1976-207.png
# filename:  OACC__1976-84.png
# filename:  OAAS_1_-_OA_Bib__2003-37.png
# filename:  OACC__1976-165.txt
# filename:  OAAS_1_-_OA_Bib__2003-54.txt
# filename:  OACC__1976-180.txt
# filename:  OAAS_1_-_OA_Bib__2003-98.txt
# filename:  OACC__1976-5.txt
# filename:  OACC__1976-179.txt
# filename:  OACC__1976-133.txt
# filename:  OACC__1976-10.txt
# filename:  OACC__1976-59.txt
# filename:  OACC__1976-66.png
# filename:  OAAS_1_-_OA_Bib__2003-98.png
# filename:  OAAS_1_-_OA_Bib__2003-77.png
# filename:  OACC__1976-137.png
# filename:  OACC__1976-80.png
# filename:  OACC__1976-30.txt
# filename:  OACC__1976-192.png
# filename:  OACC__1976-101.txt
# filename:  OACC__1976-171.png
# filename:  OAAS_1_-_OA_Bib__2003-103.png
# filename:  OACC__1976-201.txt
# filename:  OAAS_1_-_OA_Bib__2003-105.png
# filename:  OAAS_1_-_OA_Bib__2003-3.txt
# filename:  OAAS_1_-_OA_Bib__2003-75.png
# filename:  OACC__1976-87.png
# filename:  OACC__1976-108.txt
# filename:  OACC__1976-125.png
# filename:  OACC__1976-81.txt
# filename:  OAAS_1_-_OA_Bib__2003-128.png
# filename:  OAAS_1_-_OA_Bib__2003-26.txt
# filename:  OACC__1976-91.txt
# filename:  OAAS_1_-_OA_Bib__2003-30.png
# filename:  OACC__1976-6.png
# filename:  OACC__1976-71.txt
# filename:  OACC__1976-141.png
# filename:  OAAS_1_-_OA_Bib__2003-1.png
# filename:  OACC__1976-60.txt
# filename:  OACC__1976-204.png
# filename:  OACC__1976-131.txt
# filename:  OACC__1976-73.png
# filename:  OAAS_1_-_OA_Bib__2003-72.txt
# filename:  OAAS_1_-_OA_Bib__2003-69.txt
# filename:  OAAS_1_-_OA_Bib__2003-90.txt
# filename:  OACC__1976-85.txt
# filename:  OACC__1976-88.png
# filename:  OAAS_1_-_OA_Bib__2003-14.png
# filename:  OAAS_1_-_OA_Bib__2003-53.txt
# filename:  OACC__1976-183.txt
# filename:  OACC__1976-148.txt
# filename:  OAAS_1_-_OA_Bib__2003-51.txt
# filename:  OAAS_1_-_OA_Bib__2003-100.txt
# filename:  OACC__1976-75.png
# filename:  OACC__1976-20.txt
# filename:  OAAS_1_-_OA_Bib__2003-61.png
# filename:  OAAS_1_-_OA_Bib__2003-56.txt
# filename:  OAAS_1_-_OA_Bib__2003-2.txt
# filename:  OACC__1976-15.png
# filename:  OACC__1976-79.png
# filename:  OACC__1976-198.png
# filename:  OACC__1976-66.txt
# filename:  OACC__1976-29.txt
# filename:  OACC__1976-40.txt
# filename:  OACC__1976-107.png
# filename:  OAAS_1_-_OA_Bib__2003-119.png
# filename:  OAAS_1_-_OA_Bib__2003-15.txt
# filename:  OACC__1976-134.txt
# filename:  OAAS_1_-_OA_Bib__2003-88.txt
# filename:  OACC__1976-122.png
# filename:  OACC__1976-30.png
# filename:  OACC__1976-76.txt
# filename:  OAAS_1_-_OA_Bib__2003-124.png
# filename:  OAAS_1_-_OA_Bib__2003-40.txt
# filename:  OACC__1976-135.txt
# filename:  OACC__1976-61.png
# filename:  OAAS_1_-_OA_Bib__2003-91.txt
# filename:  OACC__1976-160.png
# filename:  OACC__1976.pdf
# filename:  OACC__1976-23.png
# filename:  OACC__1976-56.png
# filename:  OACC__1976-172.png
# filename:  OAAS_1_-_OA_Bib__2003-21.png
# filename:  OACC__1976-79.txt
# filename:  OAAS_1_-_OA_Bib__2003-36.txt
# filename:  OACC__1976-201.png
# filename:  OAAS_1_-_OA_Bib__2003-112.png
# filename:  OAAS_1_-_OA_Bib__2003-30.txt
# filename:  OAAS_1_-_OA_Bib__2003-47.png
# filename:  OAAS_1_-_OA_Bib__2003-66.txt
# filename:  OAAS_1_-_OA_Bib__2003-85.txt
# filename:  OACC__1976-100.txt
# filename:  OAAS_1_-_OA_Bib__2003-79.png
# filename:  OAAS_1_-_OA_Bib__2003-104.png
# filename:  OACC__1976-97.png
# filename:  OAAS_1_-_OA_Bib__2003-116.png
# filename:  OACC__1976-122.txt
# filename:  OACC__1976-9.png
# filename:  OACC__1976-54.png
# filename:  OAAS_1_-_OA_Bib__2003-128.txt
# filename:  OACC__1976-12.png
# filename:  OAAS_1_-_OA_Bib__2003-3.png
# filename:  OAAS_1_-_OA_Bib__2003-114.txt
# filename:  OAAS_1_-_OA_Bib__2003-29.txt
# filename:  OACC__1976-186.png
# filename:  OACC__1976-59.png
# filename:  OAAS_1_-_OA_Bib__2003-75.txt
# filename:  OAAS_1_-_OA_Bib__2003-102.png
# filename:  OACC__1976-162.txt
# filename:  OACC__1976-167.txt
# filename:  OAAS_1_-_OA_Bib__2003-73.txt
# filename:  OAAS_1_-_OA_Bib__2003-65.png
# filename:  OACC__1976-197.png
# filename:  OACC__1976-126.png
# filename:  OACC__1976-176.png
# filename:  OACC__1976-208.txt
# filename:  OACC__1976-27.txt
# filename:  OAAS_1_-_OA_Bib__2003-93.txt
# filename:  OACC__1976-7.txt
# filename:  OACC__1976-2.png
# filename:  OAAS_1_-_OA_Bib__2003-45.txt
# filename:  OAAS_1_-_OA_Bib__2003-39.png
# filename:  OACC__1976-84.txt
# filename:  OACC__1976-107.txt
# filename:  OACC__1976-117.png
# filename:  OAAS_1_-_OA_Bib__2003-17.txt
# filename:  OAAS_1_-_OA_Bib__2003-101.txt
# filename:  OACC__1976-188.png
# filename:  OACC__1976-200.png
# filename:  OACC__1976-156.png
# filename:  OAAS_1_-_OA_Bib__2003-92.png
# filename:  OACC__1976-198.txt
# filename:  OACC__1976-11.png
# filename:  OACC__1976-104.png
# filename:  OACC__1976-49.txt
# filename:  OACC__1976-94.txt
# filename:  OACC__1976-25.png
# filename:  OACC__1976-169.png
# filename:  OACC__1976-184.png
# filename:  OAAS_1_-_OA_Bib__2003-63.txt
# filename:  OACC__1976-196.txt
# filename:  OAAS_1_-_OA_Bib__2003-52.png
# filename:  OAAS_1_-_OA_Bib__2003-54.png
# filename:  OACC__1976-47.png
# filename:  OACC__1976-156.txt
# filename:  OACC__1976-110.png
# filename:  OACC__1976-95.png
# filename:  OACC__1976-13.png
# filename:  OAAS_1_-_OA_Bib__2003-22.png
# filename:  OACC__1976-42.txt
# filename:  OAAS_1_-_OA_Bib__2003-93.png
# filename:  OACC__1976-138.txt
# filename:  OACC__1976-63.txt
# filename:  OACC__1976-38.txt
# filename:  OACC__1976-64.png
# filename:  OAAS_1_-_OA_Bib__2003-29.png
# filename:  OACC__1976-206.txt
# filename:  OACC__1976-41.png
# filename:  OAAS_1_-_OA_Bib__2003-71.png
# filename:  OACC__1976-33.png
# filename:  OACC__1976-158.png
# filename:  OAAS_1_-_OA_Bib__2003-62.png
# filename:  OAAS_1_-_OA_Bib__2003-5.png
# filename:  OAAS_1_-_OA_Bib__2003-99.png
# filename:  OAAS_1_-_OA_Bib__2003-61.txt
# filename:  OACC__1976-188.txt
# filename:  OACC__1976-139.png
# filename:  OAAS_1_-_OA_Bib__2003-18.png
# filename:  OAAS_1_-_OA_Bib__2003-21.txt
# filename:  OACC__1976-67.png
# filename:  OACC__1976-37.png
# filename:  OAAS_1_-_OA_Bib__2003-58.png
# filename:  OACC__1976-114.png
# filename:  OACC__1976-35.txt
# filename:  OACC__1976-127.txt
# filename:  OAAS_1_-_OA_Bib__2003-126.txt
# filename:  OAAS_1_-_OA_Bib__2003-109.txt
# filename:  OACC__1976-20.png
# filename:  OACC__1976-141.txt
# filename:  OAAS_1_-_OA_Bib__2003-44.png
# filename:  OACC__1976-187.png
# filename:  OACC__1976-190.txt
# filename:  OAAS_1_-_OA_Bib__2003-23.png
# filename:  OAAS_1_-_OA_Bib__2003-122.png
# filename:  OACC__1976-14.png
# filename:  OACC__1976-124.txt
# filename:  OACC__1976-120.png
# filename:  OACC__1976-202.txt
# filename:  OAAS_1_-_OA_Bib__2003-64.txt
# filename:  OACC__1976-153.png
# filename:  OAAS_1_-_OA_Bib__2003-118.txt
# filename:  OACC__1976-109.png
# filename:  OAAS_1_-_OA_Bib__2003-62.txt
# filename:  OAAS_1_-_OA_Bib__2003-52.txt
# filename:  OACC__1976-123.png
# filename:  OACC__1976-18.png
# filename:  OACC__1976-200.txt
# filename:  OAAS_1_-_OA_Bib__2003-41.png
# filename:  OACC__1976-130.png
# filename:  OAAS_1_-_OA_Bib__2003-118.png
# filename:  OACC__1976-77.txt
# filename:  OACC__1976-99.png
# filename:  OACC__1976-203.png
# filename:  OACC__1976-6.txt
# filename:  OACC__1976-56.txt
# filename:  OACC__1976-83.png
# filename:  OACC__1976-93.txt
# filename:  OACC__1976-47.txt
# filename:  OACC__1976-139.txt
# filename:  OACC__1976-90.txt
# filename:  OAAS_1_-_OA_Bib__2003-81.txt
# filename:  OAAS_1_-_OA_Bib__2003-113.txt
# filename:  OACC__1976-147.png
# filename:  OACC__1976-106.txt
# filename:  OACC__1976-206.png
# filename:  OAAS_1_-_OA_Bib__2003-4.png
# filename:  OAAS_1_-_OA_Bib__2003-87.png
# filename:  OACC__1976-57.png
# filename:  OACC__1976-204.txt
# filename:  OACC__1976-185.png
# filename:  OAAS_1_-_OA_Bib__2003-13.txt
# filename:  OACC__1976-174.txt
# filename:  OAAS_1_-_OA_Bib__2003-70.png
# filename:  OAAS_1_-_OA_Bib__2003-58.txt
# filename:  OAAS_1_-_OA_Bib__2003-63.png
# filename:  OACC__1976-146.txt
# filename:  OAAS_1_-_OA_Bib__2003-16.txt
# filename:  OACC__1976-24.png
# filename:  OAAS_1_-_OA_Bib__2003-110.txt
# filename:  OACC__1976-187.txt
# filename:  OACC__1976-76.png
# filename:  OAAS_1_-_OA_Bib__2003-27.png
# filename:  OACC__1976-112.txt
# filename:  OACC__1976-46.png
# filename:  OACC__1976-33.txt
# filename:  OACC__1976-21.txt
# filename:  OACC__1976-155.txt
# filename:  OAAS_1_-_OA_Bib__2003-7.txt
# filename:  OACC__1976-62.png
# filename:  OACC__1976-2.txt
# filename:  OAAS_1_-_OA_Bib__2003-51.png
# filename:  OAAS_1_-_OA_Bib__2003-8.png
# filename:  OACC__1976-162.png
# filename:  OAAS_1_-_OA_Bib__2003-57.txt
# filename:  OAAS_1_-_OA_Bib__2003-47.txt
# filename:  OAAS_1_-_OA_Bib__2003-13.png
# filename:  OACC__1976-70.txt
# filename:  OAAS_1_-_OA_Bib__2003-77.txt
# filename:  OACC__1976-161.png
# filename:  OACC__1976-118.png
# filename:  OACC__1976-167.png
# filename:  OAAS_1_-_OA_Bib__2003-45.png
# filename:  OACC__1976-144.txt
# filename:  OAAS_1_-_OA_Bib__2003-14.txt
# filename:  OACC__1976-149.txt
# filename:  OACC__1976-19.txt
# filename:  OAAS_1_-_OA_Bib__2003-89.txt
# filename:  OACC__1976-90.png
# filename:  OAAS_1_-_OA_Bib__2003-46.png
# filename:  OACC__1976-176.txt
# filename:  OACC__1976-191.png
# filename:  OAAS_1_-_OA_Bib__2003-95.png
# filename:  OAAS_1_-_OA_Bib__2003-57.png
# filename:  OACC__1976-170.txt
# filename:  OACC__1976-199.txt
# filename:  OACC__1976-164.txt
# filename:  OACC__1976-195.txt
# filename:  OACC__1976-51.png
# filename:  OACC__1976-23.txt
# filename:  OAAS_1_-_OA_Bib__2003-67.txt
# filename:  OAAS_1_-_OA_Bib__2003-46.txt
# filename:  OACC__1976-52.png
# filename:  OAAS_1_-_OA_Bib__2003-10.png
# filename:  OACC__1976-209.txt
# filename:  OAAS_1_-_OA_Bib__2003-9.txt
# filename:  OACC__1976-1.txt
# filename:  OACC__1976-173.png
# filename:  OAAS_1_-_OA_Bib__2003-40.png
# filename:  OACC__1976-121.png
# filename:  OACC__1976-132.txt
# filename:  OACC__1976-88.txt
# filename:  OAAS_1_-_OA_Bib__2003-50.png
# filename:  OACC__1976-158.txt
# filename:  OACC__1976-140.txt
# filename:  OAAS_1_-_OA_Bib__2003-70.txt
# filename:  OAAS_1_-_OA_Bib__2003-119.txt
# filename:  OACC__1976-26.png
# filename:  OACC__1976-116.txt
# filename:  OACC__1976-189.png
# filename:  OAAS_1_-_OA_Bib__2003-82.png
# filename:  OACC__1976-73.txt
# filename:  OACC__1976-154.txt
# filename:  OAAS_1_-_OA_Bib__2003-64.png
# filename:  OAAS_1_-_OA_Bib__2003-32.txt
# filename:  OACC__1976-157.txt
# filename:  OACC__1976-43.png
# filename:  OACC__1976-102.png
# filename:  OACC__1976-178.png
# filename:  OAAS_1_-_OA_Bib__2003-28.png
# filename:  OAAS_1_-_OA_Bib__2003-12.png
# filename:  OACC__1976-202.png
# filename:  OAAS_1_-_OA_Bib__2003-34.txt
# filename:  OACC__1976-44.txt
# filename:  OACC__1976-69.png
# filename:  OACC__1976-171.txt
# filename:  OACC__1976-208.png
# filename:  OACC__1976-145.png
# filename:  OAAS_1_-_OA_Bib__2003-108.png
# filename:  OACC__1976-71.png
# filename:  OACC__1976-96.txt
# filename:  OACC__1976-190.png
# filename:  OAAS_1_-_OA_Bib__2003-43.png
# filename:  OACC__1976-189.txt
# filename:  OACC__1976-183.png
# filename:  OACC__1976-28.png
# filename:  OACC__1976-146.png
# filename:  OACC__1976-52.txt
# filename:  OACC__1976-3.png
# filename:  OACC__1976-49.png
# filename:  OAAS_1_-_OA_Bib__2003-90.png
# filename:  OACC__1976-120.txt
# filename:  OACC__1976-149.png
# filename:  OAAS_1_-_OA_Bib__2003-96.png
# filename:  OAAS_1_-_OA_Bib__2003-59.png
# filename:  OACC__1976-180.png
# filename:  OACC__1976-110.txt
# filename:  OACC__1976-210.png
# filename:  OAAS_1_-_OA_Bib__2003-71.txt
# filename:  OACC__1976-17.png
# filename:  OAAS_1_-_OA_Bib__2003-123.png
# filename:  OACC__1976-55.png
# filename:  OAAS_1_-_OA_Bib__2003-120.png
# filename:  OAAS_1_-_OA_Bib__2003-111.png
# filename:  OAAS_1_-_OA_Bib__2003-86.png
# filename:  OACC__1976-83.txt
# filename:  OACC__1976-37.txt
# filename:  OACC__1976-38.png
# filename:  OACC__1976-121.txt
# filename:  OACC__1976-144.png
# filename:  OACC__1976-18.txt
# filename:  OAAS_1_-_OA_Bib__2003-127.png
# filename:  OAAS_1_-_OA_Bib__2003-31.png
# filename:  OACC__1976-168.png
# filename:  OACC__1976-191.txt
# pdffileList:  ['OAAS_1_-_OA_Bib__2003.pdf', 'OACC__1976.pdf']
# filenameList:  ['OAAS_1_-_OA_Bib__2003', 'OACC__1976']

# %% [markdown]
# ### Run tesseract on all image files in the working directory

# %%
def runTesseract(imagefile):
    print("imagefile : ", imagefile)
    
    # template: tesseract --tessdata-dir /opt/tessdata /scratch/germanocr_Page_01.png  germanout  -l deu
    TCMD = 'tesseract --tessdata-dir /opt/tessdata {}{} {}{}  -l eng'
    #
    # ocr the png
    # 
    basename, ext = os.path.splitext(imagefile)
    tcmd = TCMD.format(tesseractScratchDataDirectory, imagefile, tesseractScratchDataDirectory,basename )
    print("tesseract cmd: ", tcmd)
    #print("singularity cmd: ", SINGULARITYCMD)

    result = !$SINGULARITYCMD $tcmd
    print("tesseract result: ", result)
    TCMD = 'tesseract --tessdata-dir /opt/tessdata {}{} {}{}  -l eng'

# %%
from multiprocessing import Pool

imageList = []
for imagename in os.listdir(scratchDataDirectory):
    if imagename.endswith(".png"):
        imageList.append(imagename)

#
# multiprocess the ocr work
#
#pool = Pool()
#pool.map(runTesseract, imageList)
#pool.close()
#pool.join()

# %% [markdown]
# ### Merge text files and upload to Box

# %%
import re

def natural_sort_key(s, _nsre=re.compile('([0-9]+)')):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]

# %%
print("pdfnamelist: ", pdfnamelist ) 

for name in pdfnamelist:
    mergeList = []
    for filename in os.listdir(scratchDataDirectory):
        #print("filename: ", filename)
        if filename.endswith(".txt") and filename.startswith(name): 
            mergeList.append(filename)
    #print(mergeList)

    sortedList = sorted(mergeList, key = natural_sort_key)
    #print(sortedList)

    alltextfilename = ''.join([scratchDataDirectory,name,'ALL.txt'])
    with open(alltextfilename, 'w', encoding="utf-8") as outfile:
        for fname in sortedList:
            with open(''.join([scratchDataDirectory,fname]), encoding="utf-8" ) as infile:
                for line in infile:
                    outfile.write(line)
                    
    upload_folder = client.folder(folder_id=targetfolderId).get()
    # upload the complete text file
    textfileinbox = upload_folder.upload( alltextfilename)  
    print ("text file id: ", textfileinbox['id'] )
# Out:
# pdfnamelist:  ['OAAS_1_-_OA_Bib__2003', 'OACC__1976']
# text file id:  118925180423
# text file id:  118925165127
